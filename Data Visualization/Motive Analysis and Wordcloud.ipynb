# %% [markdown]
# ## Text Processing

# %% [markdown]
# ### 1. load in data

# %%
#load in data
import pandas as pd
df = pd.read_csv(r'E:\WEMUST\Opensourcetools\final\terror2018.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Year  Month  Day   Country                      Region  \
# 0      182878  2018      1    1      Iraq  Middle East & North Africa
# 1      182879  2018      1    1      Iraq  Middle East & North Africa
# 2      182880  2018      1    1  Pakistan                  South Asia
# 3      182881  2018      1    1  Pakistan                  South Asia
# 4      182882  2018      1    1   Nigeria          Sub-Saharan Africa
#
#        city   latitude  longitude         AttackType  Killed  Wounded  \
# 0  Tal Afar  36.376825  42.448876  Bombing/Explosion     3.0      0.0
# 1    Kirkuk  35.452112  44.375464  Bombing/Explosion     0.0      0.0
# 2    Chaman  30.922110  66.451533  Bombing/Explosion     0.0      2.0
# 3    Chaman  30.922110  66.451533  Bombing/Explosion     0.0      6.0
# 4  Madagali  10.889420  13.628320  Bombing/Explosion     3.0      0.0
#
#                         Target  \
# 0                    Civilians
# 1                 Headquarters
# 2  Under-Construction Building
# 3                    Checkpost
# 4                    Civilians
#
#                                              Summary  \
# 0  01/01/2018: An explosive device detonated in T...
# 1  01/01/2018: Assailants fired three mortars at ...
# 2  01/01/2018: An explosive device detonated at a...
# 3  01/01/2018: An explosive device detonated at a...
# 4  01/01/2018: An explosive device detonated in M...
#
#                                          Group                  Target_type  \
# 0  Islamic State of Iraq and the Levant (ISIL)  Private Citizens & Property
# 1                                      Unknown  Private Citizens & Property
# 2                                      Unknown                     Business
# 3                                      Unknown                       Police
# 4                                   Boko Haram  Private Citizens & Property
#
#   Weapon_type Motive
# 0  Explosives    NaN
# 1  Explosives    NaN
# 2  Explosives    NaN
# 3  Explosives    NaN
# 4  Explosives    NaN

# %% [markdown]
# ### 2. Convert all characters to lowercase with function str.lower()
# By observing the raw text, replace \. with ' ' (sometimes '.' is linked to the next word without space, we deal with it here in order to simplify tokenization). What's more, the text is displayed in dataframe. use str.cat() function to convert them together.

# %%
#select Motive column for wordcloud display
#convert all characters to lowercase
#replace dot with space
#connect
#raw text
motive = df['Motive'].str.lower().str.replace('\.',' ').str.cat(sep = '')
#motive
# Out:
# C:\Users\SERGI\AppData\Local\Temp\ipykernel_13260\2710044425.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   motive = df['Motive'].str.lower().str.replace('\.',' ').str.cat(sep = '')

# %% [markdown]
# ### 3. remove punctuations with regular expressions

# %%
import re
#remove punctuations
#r = "[0-9_.!+-=——,$%^，;。？、``~@#￥%……&*《》<>「」{}【】()/]"
new_word = re.sub(r'[^\w\s]', '', motive)
#new_word2 = new_word.replace(r'\B\'s\b', '')
#new_word

# %% [markdown]
# ### 4. Tokenize the data using the word_tokenize() function in nltk package, which is a (...)

# %%
#tokenize the data
import nltk
word_token = nltk.word_tokenize(new_word)
#word_token

# %% [markdown]
# ### 5. Remove 's and ''

# %%
#remove 's
def remove_s(words):
    new_words = []
    for word in words:
        new_word = re.sub(r'\'s', '',word)
        new_word = re.sub(r'``', '',word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

test2 = remove_s(word_token)
#len(test2)
#test2
# Out:
# ['the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'suspected',
#  'that',
#  'the',
#  'victims',
#  'who',
#  'were',
#  'members',
#  'of',
#  'the',
#  'coptic',
#  'christian',
#  'community',
#  'may',
#  'have',
#  'been',
#  'targeted',
#  'as',
#  'part',
#  'of',
#  'a',
#  'larger',
#  'trend',
#  'of',
#  'sectarian',
#  'violence',
#  'between',
#  'egypts',
#  'majority',
#  'muslim',
#  'and',
#  'minority',
#  'christian',
#  'communities',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'selfdefense',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'selfdefense',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'selfdefense',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'posited',
#  'that',
#  'the',
#  'assailants',
#  'demanded',
#  'that',
#  'the',
#  'afghan',
#  'government',
#  'conduct',
#  'vaccination',
#  'drives',
#  'in',
#  'territory',
#  'under',
#  'taliban',
#  'control',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'selfdefense',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'noted',
#  'that',
#  'the',
#  'attack',
#  'occurred',
#  'two',
#  'days',
#  'after',
#  'five',
#  'alshabaab',
#  'members',
#  'were',
#  'killed',
#  'by',
#  'the',
#  'kenya',
#  'defense',
#  'forces',
#  'kdf',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'noted',
#  'that',
#  'the',
#  'attack',
#  'occurred',
#  'two',
#  'days',
#  'after',
#  'five',
#  'alshabaab',
#  'members',
#  'were',
#  'killed',
#  'by',
#  'the',
#  'kenya',
#  'defense',
#  'forces',
#  'kdf',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'coincided',
#  'with',
#  'the',
#  'beginning',
#  'of',
#  'the',
#  'trial',
#  'of',
#  'five',
#  'alshabaab',
#  'members',
#  'who',
#  'were',
#  'accused',
#  'of',
#  'involvement',
#  'in',
#  'the',
#  'october',
#  '14',
#  '2017',
#  'truck',
#  'bombing',
#  'in',
#  'mogadishu',
#  'sources',
#  'also',
#  'noted',
#  'that',
#  'the',
#  'victim',
#  'was',
#  'the',
#  'father',
#  'of',
#  'the',
#  'somali',
#  'military',
#  'court',
#  'chairperson',
#  'alshabaab',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'accused',
#  'of',
#  'the',
#  'victims',
#  'of',
#  'spying',
#  'for',
#  'the',
#  'kenyan',
#  'ethiopian',
#  'and',
#  'somali',
#  'governments',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'selfdefense',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'selfdefense',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'noted',
#  'that',
#  'the',
#  'targeted',
#  'lawyers',
#  'were',
#  'responsible',
#  'for',
#  'filing',
#  'terrorismrelated',
#  'lawsuits',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'suspected',
#  'that',
#  'arif',
#  'ahmad',
#  'sofi',
#  'was',
#  'targeted',
#  'in',
#  'order',
#  'to',
#  'dissuade',
#  'his',
#  'father',
#  'muhammad',
#  'maqbool',
#  'sofi',
#  'from',
#  'participating',
#  'in',
#  'the',
#  'kashmir',
#  'freedom',
#  'movement',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'stated',
#  'that',
#  'salah',
#  'iqliwan',
#  'alqatrani',
#  'had',
#  'previously',
#  'been',
#  'threatened',
#  'not',
#  'to',
#  'run',
#  'in',
#  'upcoming',
#  'parliamentary',
#  'elections',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'suspected',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'part',
#  'of',
#  'a',
#  'larger',
#  'trend',
#  'of',
#  'sectarian',
#  'violence',
#  'between',
#  'kyrgyzstans',
#  'muslim',
#  'majority',
#  'and',
#  'christian',
#  'minority',
#  'populations',
#  'sources',
#  'also',
#  'suspected',
#  'that',
#  'the',
#  'attack',
#  'may',
#  'have',
#  'been',
#  'carried',
#  'out',
#  'in',
#  'response',
#  'to',
#  'the',
#  'outreach',
#  'events',
#  'organized',
#  'by',
#  'the',
#  'targeted',
#  'church',
#  'an',
#  'unknown',
#  'group',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'demanded',
#  'a',
#  'ransom',
#  'in',
#  'exchange',
#  'for',
#  'swapan',
#  'das',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'stated',
#  'that',
#  'the',
#  'victims',
#  'were',
#  'accused',
#  'of',
#  'being',
#  'military',
#  'informants',
#  'the',
#  'sudan',
#  'peoples',
#  'liberation',
#  'movement',
#  'in',
#  'opposition',
#  'splmio',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'response',
#  'to',
#  'the',
#  'abduction',
#  'of',
#  'an',
#  'splmio',
#  'governor',
#  'in',
#  'marko',
#  'kenya',
#  'by',
#  'the',
#  'south',
#  'sudanese',
#  'government',
#  'the',
#  'sudan',
#  'peoples',
#  'liberation',
#  'movement',
#  'in',
#  'opposition',
#  'splmio',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'response',
#  'to',
#  'the',
#  'abduction',
#  'of',
#  'an',
#  'splmio',
#  'governor',
#  'in',
#  'marko',
#  'kenya',
#  'by',
#  'the',
#  'south',
#  'sudanese',
#  'government',
#  'alshabaab',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'accused',
#  'the',
#  'victims',
#  'of',
#  'working',
#  'for',
#  'the',
#  'somali',
#  'intelligence',
#  'service',
#  'the',
#  'arakan',
#  'rohingya',
#  'salvation',
#  'army',
#  'arsa',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'stated',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'response',
#  'to',
#  'the',
#  'poor',
#  'treatment',
#  'of',
#  'members',
#  'of',
#  'the',
#  'rohingya',
#  'community',
#  'in',
#  'myanmar',
#  'arsa',
#  'also',
#  'accused',
#  'the',
#  'myanmar',
#  'army',
#  'of',
#  'cutting',
#  'off',
#  'rohingyas',
#  'access',
#  'to',
#  'food',
#  'and',
#  'medical',
#  'care',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'noted',
#  'that',
#  'the',
#  'attack',
#  'occurred',
#  'the',
#  'day',
#  'after',
#  'leaders',
#  'of',
#  'the',
#  'southern',
#  'regional',
#  'military',
#  'command',
#  'visited',
#  'the',
#  'area',
#  'to',
#  'inspect',
#  'government',
#  'personnel',
#  'the',
#  'free',
#  'alawite',
#  'movement',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'demanded',
#  'that',
#  'russian',
#  'military',
#  'personnel',
#  'withdraw',
#  'from',
#  'syria',
#  'the',
#  'free',
#  'alawite',
#  'movement',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'demanded',
#  'that',
#  'russian',
#  'military',
#  'personnel',
#  'withdraw',
#  'from',
#  'syria',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'noted',
#  'that',
#  'the',
#  'attack',
#  'occurred',
#  'during',
#  'a',
#  'shutdown',
#  'in',
#  'sopore',
#  'called',
#  'by',
#  'separatists',
#  'to',
#  'commemorate',
#  'the',
#  '25th',
#  'anniversary',
#  'of',
#  'the',
#  'massacre',
#  'of',
#  'civilians',
#  'by',
#  'government',
#  'personnel',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'noted',
#  'that',
#  'the',
#  'attack',
#  'occurred',
#  'one',
#  'day',
#  'after',
#  'sheikh',
#  'haitham',
#  'alhoum',
#  'announced',
#  'the',
#  'commencement',
#  'of',
#  'a',
#  'security',
#  'operation',
#  'carried',
#  'out',
#  'by',
#  'tribal',
#  'paramilitary',
#  'groups',
#  'aiming',
#  'to',
#  'rid',
#  'the',
#  'area',
#  'of',
#  'islamic',
#  'state',
#  'of',
#  'iraq',
#  'and',
#  'the',
#  'levant',
#  'isil',
#  'members',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'suspected',
#  'that',
#  'the',
#  'attack',
#  'aimed',
#  'to',
#  'stop',
#  'the',
#  'deforestation',
#  'of',
#  'casamance',
#  'sources',
#  'also',
#  'suspected',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'related',
#  'to',
#  'the',
#  'release',
#  'of',
#  'two',
#  'movement',
#  'of',
#  'democratic',
#  'forces',
#  'of',
#  'casamance',
#  'members',
#  'from',
#  'custody',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'stated',
#  'that',
#  'houthi',
#  'extremists',
#  'ansar',
#  'allah',
#  'had',
#  'previously',
#  'threatened',
#  'to',
#  'block',
#  'shipping',
#  'routes',
#  'in',
#  'the',
#  'red',
#  'sea',
#  'in',
#  'response',
#  'to',
#  'the',
#  'advancement',
#  'of',
#  'saudiled',
#  'coalition',
#  'forces',
#  'toward',
#  'the',
#  'hudaydah',
#  'port',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'source',
#  'noted',
#  'that',
#  'musa',
#  'namir',
#  'aqwri',
#  'was',
#  'planning',
#  'to',
#  'be',
#  'a',
#  'candidate',
#  'in',
#  'libyas',
#  'upcoming',
#  'general',
#  'elections',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'suspected',
#  'that',
#  'the',
#  'attack',
#  'was',
#  'carried',
#  'out',
#  'in',
#  'relation',
#  'to',
#  'the',
#  'recently',
#  'passed',
#  'antiopen',
#  'grazing',
#  'prohibition',
#  'law',
#  'the',
#  'volunteers',
#  'of',
#  'innocent',
#  'people',
#  'of',
#  'nagas',
#  'vipn',
#  'claimed',
#  'responsibility',
#  'for',
#  'the',
#  'incident',
#  'and',
#  'demanded',
#  'that',
#  'shops',
#  'register',
#  'with',
#  'the',
#  'group',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'noted',
#  'that',
#  'the',
#  'attack',
#  'occurred',
#  'during',
#  'ongoing',
#  'local',
#  'elections',
#  'in',
#  'delta',
#  'state',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'stated',
#  'that',
#  'pandru',
#  'was',
#  'suspected',
#  'of',
#  'being',
#  'a',
#  'police',
#  'informant',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'stated',
#  'that',
#  'nuri',
#  'alabaish',
#  'was',
#  'a',
#  'critic',
#  'of',
#  'the',
#  'islamic',
#  'state',
#  'of',
#  'iraq',
#  'and',
#  'the',
#  'levant',
#  'isil',
#  'and',
#  'had',
#  'previously',
#  'headed',
#  'an',
#  'operation',
#  'to',
#  'push',
#  'relatives',
#  'of',
#  'isil',
#  'members',
#  'out',
#  'of',
#  'alshirqat',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'suspected',
#  'that',
#  'the',
#  'attack',
#  'aimed',
#  'to',
#  'obstruct',
#  'communication',
#  'in',
#  'the',
#  'area',
#  'so',
#  'that',
#  'alshabaab',
#  'could',
#  'carry',
#  'out',
#  'additional',
#  'attacks',
#  'unimpeded',
#  'the',
#  'specific',
#  'motive',
#  'is',
#  'unknown',
#  'however',
#  'sources',
#  'stated',
#  'that',
#  'the',
#  'explosive',
#  'device',
#  'was',
#  'purposefully',
#  'planted',
#  'along',
#  'the',
#  'route',
#  'that',
#  'security',
#  'forces',
#  'traveled',
#  'on',
#  ...]

# %% [markdown]
# ### 6. remove stopwords from nltk package

# %%
#remove stopwords
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
#my_stopwords = set(stopwords.words('english'))
#stopword_list = ['s','e','t','n']
my_stopwords = set(STOPWORDS)  
#for i in stopword_list:
#   my_stopwords.add(i)
#my_stopwords
def remove_stopwords(words):
    new_words = []
    for word in words:
        if word not in my_stopwords:
            new_words.append(word)
    return new_words
test3 = remove_stopwords(test2)
#test3
# Out:
# ['specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'victims',
#  'members',
#  'coptic',
#  'christian',
#  'community',
#  'may',
#  'targeted',
#  'part',
#  'larger',
#  'trend',
#  'sectarian',
#  'violence',
#  'egypts',
#  'majority',
#  'muslim',
#  'minority',
#  'christian',
#  'communities',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'posited',
#  'assailants',
#  'demanded',
#  'afghan',
#  'government',
#  'conduct',
#  'vaccination',
#  'drives',
#  'territory',
#  'taliban',
#  'control',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'two',
#  'days',
#  'five',
#  'alshabaab',
#  'members',
#  'killed',
#  'kenya',
#  'defense',
#  'forces',
#  'kdf',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'two',
#  'days',
#  'five',
#  'alshabaab',
#  'members',
#  'killed',
#  'kenya',
#  'defense',
#  'forces',
#  'kdf',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'attack',
#  'coincided',
#  'beginning',
#  'trial',
#  'five',
#  'alshabaab',
#  'members',
#  'accused',
#  'involvement',
#  'october',
#  '14',
#  '2017',
#  'truck',
#  'bombing',
#  'mogadishu',
#  'sources',
#  'noted',
#  'victim',
#  'father',
#  'somali',
#  'military',
#  'court',
#  'chairperson',
#  'alshabaab',
#  'claimed',
#  'responsibility',
#  'incident',
#  'accused',
#  'victims',
#  'spying',
#  'kenyan',
#  'ethiopian',
#  'somali',
#  'governments',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'fulani',
#  'extremists',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'targeted',
#  'lawyers',
#  'responsible',
#  'filing',
#  'terrorismrelated',
#  'lawsuits',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'arif',
#  'ahmad',
#  'sofi',
#  'targeted',
#  'order',
#  'dissuade',
#  'father',
#  'muhammad',
#  'maqbool',
#  'sofi',
#  'participating',
#  'kashmir',
#  'freedom',
#  'movement',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'salah',
#  'iqliwan',
#  'alqatrani',
#  'previously',
#  'threatened',
#  'run',
#  'upcoming',
#  'parliamentary',
#  'elections',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'attack',
#  'part',
#  'larger',
#  'trend',
#  'sectarian',
#  'violence',
#  'kyrgyzstans',
#  'muslim',
#  'majority',
#  'christian',
#  'minority',
#  'populations',
#  'sources',
#  'suspected',
#  'attack',
#  'may',
#  'carried',
#  'response',
#  'outreach',
#  'events',
#  'organized',
#  'targeted',
#  'church',
#  'unknown',
#  'group',
#  'claimed',
#  'responsibility',
#  'incident',
#  'demanded',
#  'ransom',
#  'exchange',
#  'swapan',
#  'das',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'victims',
#  'accused',
#  'military',
#  'informants',
#  'sudan',
#  'peoples',
#  'liberation',
#  'movement',
#  'opposition',
#  'splmio',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'abduction',
#  'splmio',
#  'governor',
#  'marko',
#  'kenya',
#  'south',
#  'sudanese',
#  'government',
#  'sudan',
#  'peoples',
#  'liberation',
#  'movement',
#  'opposition',
#  'splmio',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'abduction',
#  'splmio',
#  'governor',
#  'marko',
#  'kenya',
#  'south',
#  'sudanese',
#  'government',
#  'alshabaab',
#  'claimed',
#  'responsibility',
#  'incident',
#  'accused',
#  'victims',
#  'working',
#  'somali',
#  'intelligence',
#  'service',
#  'arakan',
#  'rohingya',
#  'salvation',
#  'army',
#  'arsa',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'poor',
#  'treatment',
#  'members',
#  'rohingya',
#  'community',
#  'myanmar',
#  'arsa',
#  'accused',
#  'myanmar',
#  'army',
#  'cutting',
#  'rohingyas',
#  'access',
#  'food',
#  'medical',
#  'care',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'day',
#  'leaders',
#  'southern',
#  'regional',
#  'military',
#  'command',
#  'visited',
#  'area',
#  'inspect',
#  'government',
#  'personnel',
#  'free',
#  'alawite',
#  'movement',
#  'claimed',
#  'responsibility',
#  'incident',
#  'demanded',
#  'russian',
#  'military',
#  'personnel',
#  'withdraw',
#  'syria',
#  'free',
#  'alawite',
#  'movement',
#  'claimed',
#  'responsibility',
#  'incident',
#  'demanded',
#  'russian',
#  'military',
#  'personnel',
#  'withdraw',
#  'syria',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'shutdown',
#  'sopore',
#  'called',
#  'separatists',
#  'commemorate',
#  '25th',
#  'anniversary',
#  'massacre',
#  'civilians',
#  'government',
#  'personnel',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'one',
#  'day',
#  'sheikh',
#  'haitham',
#  'alhoum',
#  'announced',
#  'commencement',
#  'security',
#  'operation',
#  'carried',
#  'tribal',
#  'paramilitary',
#  'groups',
#  'aiming',
#  'rid',
#  'area',
#  'islamic',
#  'state',
#  'iraq',
#  'levant',
#  'isil',
#  'members',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'attack',
#  'aimed',
#  'stop',
#  'deforestation',
#  'casamance',
#  'sources',
#  'suspected',
#  'attack',
#  'related',
#  'release',
#  'two',
#  'movement',
#  'democratic',
#  'forces',
#  'casamance',
#  'members',
#  'custody',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'houthi',
#  'extremists',
#  'ansar',
#  'allah',
#  'previously',
#  'threatened',
#  'block',
#  'shipping',
#  'routes',
#  'red',
#  'sea',
#  'response',
#  'advancement',
#  'saudiled',
#  'coalition',
#  'forces',
#  'toward',
#  'hudaydah',
#  'port',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'musa',
#  'namir',
#  'aqwri',
#  'planning',
#  'candidate',
#  'libyas',
#  'upcoming',
#  'general',
#  'elections',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'attack',
#  'carried',
#  'relation',
#  'recently',
#  'passed',
#  'antiopen',
#  'grazing',
#  'prohibition',
#  'law',
#  'volunteers',
#  'innocent',
#  'people',
#  'nagas',
#  'vipn',
#  'claimed',
#  'responsibility',
#  'incident',
#  'demanded',
#  'shops',
#  'register',
#  'group',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'ongoing',
#  'local',
#  'elections',
#  'delta',
#  'state',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'pandru',
#  'suspected',
#  'police',
#  'informant',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'nuri',
#  'alabaish',
#  'critic',
#  'islamic',
#  'state',
#  'iraq',
#  'levant',
#  'isil',
#  'previously',
#  'headed',
#  'operation',
#  'push',
#  'relatives',
#  'isil',
#  'members',
#  'alshirqat',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'attack',
#  'aimed',
#  'obstruct',
#  'communication',
#  'area',
#  'alshabaab',
#  'carry',
#  'additional',
#  'attacks',
#  'unimpeded',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'explosive',
#  'device',
#  'purposefully',
#  'planted',
#  'along',
#  'route',
#  'security',
#  'forces',
#  'traveled',
#  'antimaoist',
#  'operations',
#  'gangaloor',
#  'bhairamgarh',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'explosive',
#  'device',
#  'purposefully',
#  'planted',
#  'along',
#  'route',
#  'security',
#  'forces',
#  'traveled',
#  'antimaoist',
#  'operations',
#  'gangaloor',
#  'bhairamgarh',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'explosive',
#  'device',
#  'purposefully',
#  'planted',
#  'along',
#  'route',
#  'security',
#  'forces',
#  'traveled',
#  'antimaoist',
#  'operations',
#  'gangaloor',
#  'bhairamgarh',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'deniz',
#  'naki',
#  'prokurdish',
#  'critical',
#  'turkish',
#  'government',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'coincided',
#  '96th',
#  'anniversary',
#  'iraqi',
#  'police',
#  'day',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'coincided',
#  '96th',
#  'anniversary',
#  'iraqi',
#  'police',
#  'day',
#  'tehrikitaliban',
#  'pakistan',
#  'ttp',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'killing',
#  'ttp',
#  'members',
#  'security',
#  'forces',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'posited',
#  'incident',
#  'intended',
#  'divert',
#  'attention',
#  'security',
#  'forces',
#  'bangsamoro',
#  'islamic',
#  'freedom',
#  'movement',
#  'bifm',
#  'retreated',
#  'area',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'may',
#  'antisemitic',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'attempted',
#  'attack',
#  'carried',
#  'response',
#  'movement',
#  'security',
#  'personnel',
#  'area',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'victims',
#  'abducted',
#  'lords',
#  'resistance',
#  'army',
#  'lra',
#  'increase',
#  'membership',
#  'intensify',
#  'attacks',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'attack',
#  'occurred',
#  'amid',
#  'protests',
#  'throughout',
#  'tunisia',
#  'higher',
#  'taxes',
#  'introduced',
#  'january',
#  '1',
#  '2018',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'attack',
#  'occurred',
#  'amid',
#  'protests',
#  'throughout',
#  'tunisia',
#  'higher',
#  'taxes',
#  'introduced',
#  'january',
#  '1',
#  '2018',
#  'maoists',
#  'claimed',
#  'responsibility',
#  'attack',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'road',
#  'construction',
#  'project',
#  'group',
#  'opposed',
#  'maoists',
#  'demanded',
#  'construction',
#  'company',
#  'pay',
#  'male',
#  'female',
#  'workers',
#  'equally',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'attack',
#  'aimed',
#  'divert',
#  'attention',
#  'security',
#  'forces',
#  'operations',
#  'maguindanao',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'noted',
#  'attack',
#  'coincided',
#  'fifth',
#  'anniversary',
#  'beginning',
#  'frances',
#  'operation',
#  'serval',
#  'brought',
#  'french',
#  'forces',
#  'mali',
#  'fight',
#  'tuareg',
#  'separatists',
#  'armed',
#  'islamist',
#  'groups',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'continued',
#  'killing',
#  'yemeni',
#  'civilians',
#  'saudiled',
#  'coalition',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'victims',
#  'abducted',
#  'lords',
#  'resistance',
#  'army',
#  'lra',
#  'increase',
#  'membership',
#  'intensify',
#  'attacks',
#  'specific',
#  'motive',
#  'unknown',
#  'sources',
#  'suspected',
#  'attack',
#  'aimed',
#  'divert',
#  'attention',
#  'security',
#  'forces',
#  'operations',
#  'maguindanao',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'peoples',
#  'bodies',
#  'ideas',
#  'acts',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'days',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'peoples',
#  'bodies',
#  'ideas',
#  'acts',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'days',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'peoples',
#  'bodies',
#  'ideas',
#  'acts',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'days',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'peoples',
#  'bodies',
#  'ideas',
#  'acts',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'days',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'peoples',
#  'bodies',
#  'ideas',
#  'acts',
#  'sources',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'days',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  ...]

# %%
#print(my_stopwords)
# Out:
# {"they've", 'any', 'herself', 'yourselves', 'against', "here's", "she's", "they'd", 'had', 'both', 'through', 'each', 'because', 'are', "where's", 'to', 'should', 'but', 'own', 'else', "isn't", 'himself', 'than', "haven't", 'down', 'nor', "you'd", 'cannot', "i've", 'about', "she'll", "she'd", 'there', 'with', "didn't", 'otherwise', 'them', "what's", 'yours', 'its', "won't", 'who', "i'm", "shan't", "why's", "hasn't", 'these', "weren't", 'do', 'themselves', 'been', 'very', 'into', 'she', 'it', 'our', 'your', 'over', 'an', 'here', 'a', 'on', "i'll", 'out', "couldn't", "there's", 'be', 'can', 'again', 'does', 'of', 'were', 'this', "he'll", 'was', 'before', 'their', 'am', 'me', "how's", 'once', 'hers', 'k', 'would', 'r', "they're", 'such', "don't", "let's", 'myself', 'then', "hadn't", 'if', 'no', "you've", 'could', 'for', 'however', 'is', 'why', 'by', "i'd", 'since', "we're", 'have', 'i', 'shall', 'the', "we've", 'at', 'just', 'yourself', 'under', 'ours', "mustn't", 'that', 'has', 'we', 'and', 'him', 'itself', 'when', 'while', "you'll", 'ever', 'more', "shouldn't", 'so', 'few', 'between', 'get', 'those', "wasn't", "it's", 'my', 'www', "we'd", 'hence', 'as', 'from', 'they', "when's", 'whom', 'like', 'too', 'above', 'http', "aren't", 'therefore', 'after', "that's", 'com', "who's", 'doing', 'ourselves', 'until', 'below', 'also', 'some', 'how', 'did', 'off', 'having', 'not', 'his', "wouldn't", "they'll", "he's", 'most', 'further', 'up', "we'll", 'you', 'in', 'other', "he'd", 'or', 'theirs', 'where', 'only', "you're", 'he', 'being', 'which', 'her', 'same', 'what', 'ought', "doesn't", 'during', "can't", 'all'}

# %% [markdown]
# ### 7. Lemmatization
# Most of the Motives are written in past tense. We need to turn a word into its lemma using lemmatize() function.

# %%
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
lemmed = [WordNetLemmatizer().lemmatize(w) for w in test3]
pos_tags = nltk.pos_tag(lemmed)#词性划分
#pos_tags[:10]
#lemmed
# Out:
# ['specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'victim',
#  'member',
#  'coptic',
#  'christian',
#  'community',
#  'may',
#  'targeted',
#  'part',
#  'larger',
#  'trend',
#  'sectarian',
#  'violence',
#  'egypt',
#  'majority',
#  'muslim',
#  'minority',
#  'christian',
#  'community',
#  'fulani',
#  'extremist',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'fulani',
#  'extremist',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'fulani',
#  'extremist',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'posited',
#  'assailant',
#  'demanded',
#  'afghan',
#  'government',
#  'conduct',
#  'vaccination',
#  'drive',
#  'territory',
#  'taliban',
#  'control',
#  'fulani',
#  'extremist',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'two',
#  'day',
#  'five',
#  'alshabaab',
#  'member',
#  'killed',
#  'kenya',
#  'defense',
#  'force',
#  'kdf',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'two',
#  'day',
#  'five',
#  'alshabaab',
#  'member',
#  'killed',
#  'kenya',
#  'defense',
#  'force',
#  'kdf',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'attack',
#  'coincided',
#  'beginning',
#  'trial',
#  'five',
#  'alshabaab',
#  'member',
#  'accused',
#  'involvement',
#  'october',
#  '14',
#  '2017',
#  'truck',
#  'bombing',
#  'mogadishu',
#  'source',
#  'noted',
#  'victim',
#  'father',
#  'somali',
#  'military',
#  'court',
#  'chairperson',
#  'alshabaab',
#  'claimed',
#  'responsibility',
#  'incident',
#  'accused',
#  'victim',
#  'spying',
#  'kenyan',
#  'ethiopian',
#  'somali',
#  'government',
#  'fulani',
#  'extremist',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'fulani',
#  'extremist',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'selfdefense',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'targeted',
#  'lawyer',
#  'responsible',
#  'filing',
#  'terrorismrelated',
#  'lawsuit',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'arif',
#  'ahmad',
#  'sofi',
#  'targeted',
#  'order',
#  'dissuade',
#  'father',
#  'muhammad',
#  'maqbool',
#  'sofi',
#  'participating',
#  'kashmir',
#  'freedom',
#  'movement',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'salah',
#  'iqliwan',
#  'alqatrani',
#  'previously',
#  'threatened',
#  'run',
#  'upcoming',
#  'parliamentary',
#  'election',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'attack',
#  'part',
#  'larger',
#  'trend',
#  'sectarian',
#  'violence',
#  'kyrgyzstan',
#  'muslim',
#  'majority',
#  'christian',
#  'minority',
#  'population',
#  'source',
#  'suspected',
#  'attack',
#  'may',
#  'carried',
#  'response',
#  'outreach',
#  'event',
#  'organized',
#  'targeted',
#  'church',
#  'unknown',
#  'group',
#  'claimed',
#  'responsibility',
#  'incident',
#  'demanded',
#  'ransom',
#  'exchange',
#  'swapan',
#  'da',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'victim',
#  'accused',
#  'military',
#  'informant',
#  'sudan',
#  'people',
#  'liberation',
#  'movement',
#  'opposition',
#  'splmio',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'abduction',
#  'splmio',
#  'governor',
#  'marko',
#  'kenya',
#  'south',
#  'sudanese',
#  'government',
#  'sudan',
#  'people',
#  'liberation',
#  'movement',
#  'opposition',
#  'splmio',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'abduction',
#  'splmio',
#  'governor',
#  'marko',
#  'kenya',
#  'south',
#  'sudanese',
#  'government',
#  'alshabaab',
#  'claimed',
#  'responsibility',
#  'incident',
#  'accused',
#  'victim',
#  'working',
#  'somali',
#  'intelligence',
#  'service',
#  'arakan',
#  'rohingya',
#  'salvation',
#  'army',
#  'arsa',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'poor',
#  'treatment',
#  'member',
#  'rohingya',
#  'community',
#  'myanmar',
#  'arsa',
#  'accused',
#  'myanmar',
#  'army',
#  'cutting',
#  'rohingyas',
#  'access',
#  'food',
#  'medical',
#  'care',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'day',
#  'leader',
#  'southern',
#  'regional',
#  'military',
#  'command',
#  'visited',
#  'area',
#  'inspect',
#  'government',
#  'personnel',
#  'free',
#  'alawite',
#  'movement',
#  'claimed',
#  'responsibility',
#  'incident',
#  'demanded',
#  'russian',
#  'military',
#  'personnel',
#  'withdraw',
#  'syria',
#  'free',
#  'alawite',
#  'movement',
#  'claimed',
#  'responsibility',
#  'incident',
#  'demanded',
#  'russian',
#  'military',
#  'personnel',
#  'withdraw',
#  'syria',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'shutdown',
#  'sopore',
#  'called',
#  'separatist',
#  'commemorate',
#  '25th',
#  'anniversary',
#  'massacre',
#  'civilian',
#  'government',
#  'personnel',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'one',
#  'day',
#  'sheikh',
#  'haitham',
#  'alhoum',
#  'announced',
#  'commencement',
#  'security',
#  'operation',
#  'carried',
#  'tribal',
#  'paramilitary',
#  'group',
#  'aiming',
#  'rid',
#  'area',
#  'islamic',
#  'state',
#  'iraq',
#  'levant',
#  'isil',
#  'member',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'attack',
#  'aimed',
#  'stop',
#  'deforestation',
#  'casamance',
#  'source',
#  'suspected',
#  'attack',
#  'related',
#  'release',
#  'two',
#  'movement',
#  'democratic',
#  'force',
#  'casamance',
#  'member',
#  'custody',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'houthi',
#  'extremist',
#  'ansar',
#  'allah',
#  'previously',
#  'threatened',
#  'block',
#  'shipping',
#  'route',
#  'red',
#  'sea',
#  'response',
#  'advancement',
#  'saudiled',
#  'coalition',
#  'force',
#  'toward',
#  'hudaydah',
#  'port',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'musa',
#  'namir',
#  'aqwri',
#  'planning',
#  'candidate',
#  'libya',
#  'upcoming',
#  'general',
#  'election',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'attack',
#  'carried',
#  'relation',
#  'recently',
#  'passed',
#  'antiopen',
#  'grazing',
#  'prohibition',
#  'law',
#  'volunteer',
#  'innocent',
#  'people',
#  'naga',
#  'vipn',
#  'claimed',
#  'responsibility',
#  'incident',
#  'demanded',
#  'shop',
#  'register',
#  'group',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'ongoing',
#  'local',
#  'election',
#  'delta',
#  'state',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'pandru',
#  'suspected',
#  'police',
#  'informant',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'nuri',
#  'alabaish',
#  'critic',
#  'islamic',
#  'state',
#  'iraq',
#  'levant',
#  'isil',
#  'previously',
#  'headed',
#  'operation',
#  'push',
#  'relative',
#  'isil',
#  'member',
#  'alshirqat',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'attack',
#  'aimed',
#  'obstruct',
#  'communication',
#  'area',
#  'alshabaab',
#  'carry',
#  'additional',
#  'attack',
#  'unimpeded',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'explosive',
#  'device',
#  'purposefully',
#  'planted',
#  'along',
#  'route',
#  'security',
#  'force',
#  'traveled',
#  'antimaoist',
#  'operation',
#  'gangaloor',
#  'bhairamgarh',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'explosive',
#  'device',
#  'purposefully',
#  'planted',
#  'along',
#  'route',
#  'security',
#  'force',
#  'traveled',
#  'antimaoist',
#  'operation',
#  'gangaloor',
#  'bhairamgarh',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'explosive',
#  'device',
#  'purposefully',
#  'planted',
#  'along',
#  'route',
#  'security',
#  'force',
#  'traveled',
#  'antimaoist',
#  'operation',
#  'gangaloor',
#  'bhairamgarh',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'deniz',
#  'naki',
#  'prokurdish',
#  'critical',
#  'turkish',
#  'government',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'coincided',
#  '96th',
#  'anniversary',
#  'iraqi',
#  'police',
#  'day',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'coincided',
#  '96th',
#  'anniversary',
#  'iraqi',
#  'police',
#  'day',
#  'tehrikitaliban',
#  'pakistan',
#  'ttp',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'killing',
#  'ttp',
#  'member',
#  'security',
#  'force',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'posited',
#  'incident',
#  'intended',
#  'divert',
#  'attention',
#  'security',
#  'force',
#  'bangsamoro',
#  'islamic',
#  'freedom',
#  'movement',
#  'bifm',
#  'retreated',
#  'area',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'may',
#  'antisemitic',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'attempted',
#  'attack',
#  'carried',
#  'response',
#  'movement',
#  'security',
#  'personnel',
#  'area',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'victim',
#  'abducted',
#  'lord',
#  'resistance',
#  'army',
#  'lra',
#  'increase',
#  'membership',
#  'intensify',
#  'attack',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'attack',
#  'occurred',
#  'amid',
#  'protest',
#  'throughout',
#  'tunisia',
#  'higher',
#  'tax',
#  'introduced',
#  'january',
#  '1',
#  '2018',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'attack',
#  'occurred',
#  'amid',
#  'protest',
#  'throughout',
#  'tunisia',
#  'higher',
#  'tax',
#  'introduced',
#  'january',
#  '1',
#  '2018',
#  'maoist',
#  'claimed',
#  'responsibility',
#  'attack',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'road',
#  'construction',
#  'project',
#  'group',
#  'opposed',
#  'maoist',
#  'demanded',
#  'construction',
#  'company',
#  'pay',
#  'male',
#  'female',
#  'worker',
#  'equally',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'attack',
#  'aimed',
#  'divert',
#  'attention',
#  'security',
#  'force',
#  'operation',
#  'maguindanao',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'noted',
#  'attack',
#  'coincided',
#  'fifth',
#  'anniversary',
#  'beginning',
#  'france',
#  'operation',
#  'serval',
#  'brought',
#  'french',
#  'force',
#  'mali',
#  'fight',
#  'tuareg',
#  'separatist',
#  'armed',
#  'islamist',
#  'group',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'stated',
#  'attack',
#  'carried',
#  'response',
#  'continued',
#  'killing',
#  'yemeni',
#  'civilian',
#  'saudiled',
#  'coalition',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'victim',
#  'abducted',
#  'lord',
#  'resistance',
#  'army',
#  'lra',
#  'increase',
#  'membership',
#  'intensify',
#  'attack',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspected',
#  'attack',
#  'aimed',
#  'divert',
#  'attention',
#  'security',
#  'force',
#  'operation',
#  'maguindanao',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claimed',
#  'responsibility',
#  'incident',
#  'stated',
#  'attack',
#  'religion',
#  'expressed',
#  'discontent',
#  'perceived',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'noted',
#  'attack',
#  'occurred',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'scheduled',
#  'visit',
#  'chile',
#  ...]

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

# %%
from nltk.corpus import wordnet
wnl = WordNetLemmatizer()
lemmas_sent = []
for tag in pos_tags:
    wordnet_pos = get_wordnet_pos(tag[1]) or wordnet.NOUN
    lemmas_sent.append(wnl.lemmatize(tag[0], pos=wordnet_pos)) # 词形还原
#lemmas_sent
# Out:
# ['specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'victim',
#  'member',
#  'coptic',
#  'christian',
#  'community',
#  'may',
#  'target',
#  'part',
#  'large',
#  'trend',
#  'sectarian',
#  'violence',
#  'egypt',
#  'majority',
#  'muslim',
#  'minority',
#  'christian',
#  'community',
#  'fulani',
#  'extremist',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carry',
#  'selfdefense',
#  'fulani',
#  'extremist',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carry',
#  'selfdefense',
#  'fulani',
#  'extremist',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carry',
#  'selfdefense',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'posit',
#  'assailant',
#  'demand',
#  'afghan',
#  'government',
#  'conduct',
#  'vaccination',
#  'drive',
#  'territory',
#  'taliban',
#  'control',
#  'fulani',
#  'extremist',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carry',
#  'selfdefense',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'occurred',
#  'two',
#  'day',
#  'five',
#  'alshabaab',
#  'member',
#  'kill',
#  'kenya',
#  'defense',
#  'force',
#  'kdf',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'occurred',
#  'two',
#  'day',
#  'five',
#  'alshabaab',
#  'member',
#  'kill',
#  'kenya',
#  'defense',
#  'force',
#  'kdf',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'attack',
#  'coincide',
#  'begin',
#  'trial',
#  'five',
#  'alshabaab',
#  'member',
#  'accuse',
#  'involvement',
#  'october',
#  '14',
#  '2017',
#  'truck',
#  'bomb',
#  'mogadishu',
#  'source',
#  'note',
#  'victim',
#  'father',
#  'somali',
#  'military',
#  'court',
#  'chairperson',
#  'alshabaab',
#  'claim',
#  'responsibility',
#  'incident',
#  'accuse',
#  'victim',
#  'spy',
#  'kenyan',
#  'ethiopian',
#  'somali',
#  'government',
#  'fulani',
#  'extremist',
#  'claimed',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carry',
#  'selfdefense',
#  'fulani',
#  'extremist',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carry',
#  'selfdefense',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'targeted',
#  'lawyer',
#  'responsible',
#  'filing',
#  'terrorismrelated',
#  'lawsuit',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'arif',
#  'ahmad',
#  'sofi',
#  'target',
#  'order',
#  'dissuade',
#  'father',
#  'muhammad',
#  'maqbool',
#  'sofi',
#  'participate',
#  'kashmir',
#  'freedom',
#  'movement',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'salah',
#  'iqliwan',
#  'alqatrani',
#  'previously',
#  'threaten',
#  'run',
#  'upcoming',
#  'parliamentary',
#  'election',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'attack',
#  'part',
#  'large',
#  'trend',
#  'sectarian',
#  'violence',
#  'kyrgyzstan',
#  'muslim',
#  'majority',
#  'christian',
#  'minority',
#  'population',
#  'source',
#  'suspect',
#  'attack',
#  'may',
#  'carry',
#  'response',
#  'outreach',
#  'event',
#  'organize',
#  'target',
#  'church',
#  'unknown',
#  'group',
#  'claim',
#  'responsibility',
#  'incident',
#  'demand',
#  'ransom',
#  'exchange',
#  'swapan',
#  'da',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'victim',
#  'accuse',
#  'military',
#  'informant',
#  'sudan',
#  'people',
#  'liberation',
#  'movement',
#  'opposition',
#  'splmio',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carry',
#  'response',
#  'abduction',
#  'splmio',
#  'governor',
#  'marko',
#  'kenya',
#  'south',
#  'sudanese',
#  'government',
#  'sudan',
#  'people',
#  'liberation',
#  'movement',
#  'opposition',
#  'splmio',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carry',
#  'response',
#  'abduction',
#  'splmio',
#  'governor',
#  'marko',
#  'kenya',
#  'south',
#  'sudanese',
#  'government',
#  'alshabaab',
#  'claim',
#  'responsibility',
#  'incident',
#  'accuse',
#  'victim',
#  'work',
#  'somali',
#  'intelligence',
#  'service',
#  'arakan',
#  'rohingya',
#  'salvation',
#  'army',
#  'arsa',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carry',
#  'response',
#  'poor',
#  'treatment',
#  'member',
#  'rohingya',
#  'community',
#  'myanmar',
#  'arsa',
#  'accuse',
#  'myanmar',
#  'army',
#  'cut',
#  'rohingyas',
#  'access',
#  'food',
#  'medical',
#  'care',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'occur',
#  'day',
#  'leader',
#  'southern',
#  'regional',
#  'military',
#  'command',
#  'visit',
#  'area',
#  'inspect',
#  'government',
#  'personnel',
#  'free',
#  'alawite',
#  'movement',
#  'claim',
#  'responsibility',
#  'incident',
#  'demand',
#  'russian',
#  'military',
#  'personnel',
#  'withdraw',
#  'syria',
#  'free',
#  'alawite',
#  'movement',
#  'claim',
#  'responsibility',
#  'incident',
#  'demand',
#  'russian',
#  'military',
#  'personnel',
#  'withdraw',
#  'syria',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'occur',
#  'shutdown',
#  'sopore',
#  'call',
#  'separatist',
#  'commemorate',
#  '25th',
#  'anniversary',
#  'massacre',
#  'civilian',
#  'government',
#  'personnel',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'occur',
#  'one',
#  'day',
#  'sheikh',
#  'haitham',
#  'alhoum',
#  'announce',
#  'commencement',
#  'security',
#  'operation',
#  'carry',
#  'tribal',
#  'paramilitary',
#  'group',
#  'aim',
#  'rid',
#  'area',
#  'islamic',
#  'state',
#  'iraq',
#  'levant',
#  'isil',
#  'member',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'attack',
#  'aim',
#  'stop',
#  'deforestation',
#  'casamance',
#  'source',
#  'suspect',
#  'attack',
#  'related',
#  'release',
#  'two',
#  'movement',
#  'democratic',
#  'force',
#  'casamance',
#  'member',
#  'custody',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'houthi',
#  'extremist',
#  'ansar',
#  'allah',
#  'previously',
#  'threaten',
#  'block',
#  'ship',
#  'route',
#  'red',
#  'sea',
#  'response',
#  'advancement',
#  'saudiled',
#  'coalition',
#  'force',
#  'toward',
#  'hudaydah',
#  'port',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'musa',
#  'namir',
#  'aqwri',
#  'plan',
#  'candidate',
#  'libya',
#  'upcoming',
#  'general',
#  'election',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'attack',
#  'carry',
#  'relation',
#  'recently',
#  'pass',
#  'antiopen',
#  'graze',
#  'prohibition',
#  'law',
#  'volunteer',
#  'innocent',
#  'people',
#  'naga',
#  'vipn',
#  'claim',
#  'responsibility',
#  'incident',
#  'demand',
#  'shop',
#  'register',
#  'group',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'occur',
#  'ongoing',
#  'local',
#  'election',
#  'delta',
#  'state',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'pandru',
#  'suspect',
#  'police',
#  'informant',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'nuri',
#  'alabaish',
#  'critic',
#  'islamic',
#  'state',
#  'iraq',
#  'levant',
#  'isil',
#  'previously',
#  'head',
#  'operation',
#  'push',
#  'relative',
#  'isil',
#  'member',
#  'alshirqat',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'attack',
#  'aim',
#  'obstruct',
#  'communication',
#  'area',
#  'alshabaab',
#  'carry',
#  'additional',
#  'attack',
#  'unimpeded',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'explosive',
#  'device',
#  'purposefully',
#  'plant',
#  'along',
#  'route',
#  'security',
#  'force',
#  'travel',
#  'antimaoist',
#  'operation',
#  'gangaloor',
#  'bhairamgarh',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'explosive',
#  'device',
#  'purposefully',
#  'plant',
#  'along',
#  'route',
#  'security',
#  'force',
#  'travel',
#  'antimaoist',
#  'operation',
#  'gangaloor',
#  'bhairamgarh',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'explosive',
#  'device',
#  'purposefully',
#  'plant',
#  'along',
#  'route',
#  'security',
#  'force',
#  'travel',
#  'antimaoist',
#  'operation',
#  'gangaloor',
#  'bhairamgarh',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'deniz',
#  'naki',
#  'prokurdish',
#  'critical',
#  'turkish',
#  'government',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'coincide',
#  '96th',
#  'anniversary',
#  'iraqi',
#  'police',
#  'day',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'coincide',
#  '96th',
#  'anniversary',
#  'iraqi',
#  'police',
#  'day',
#  'tehrikitaliban',
#  'pakistan',
#  'ttp',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'carried',
#  'response',
#  'kill',
#  'ttp',
#  'member',
#  'security',
#  'force',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'posit',
#  'incident',
#  'intend',
#  'divert',
#  'attention',
#  'security',
#  'force',
#  'bangsamoro',
#  'islamic',
#  'freedom',
#  'movement',
#  'bifm',
#  'retreat',
#  'area',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'may',
#  'antisemitic',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'attempted',
#  'attack',
#  'carry',
#  'response',
#  'movement',
#  'security',
#  'personnel',
#  'area',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'victim',
#  'abduct',
#  'lord',
#  'resistance',
#  'army',
#  'lra',
#  'increase',
#  'membership',
#  'intensify',
#  'attack',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'attack',
#  'occur',
#  'amid',
#  'protest',
#  'throughout',
#  'tunisia',
#  'high',
#  'tax',
#  'introduce',
#  'january',
#  '1',
#  '2018',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'attack',
#  'occur',
#  'amid',
#  'protest',
#  'throughout',
#  'tunisia',
#  'high',
#  'tax',
#  'introduce',
#  'january',
#  '1',
#  '2018',
#  'maoist',
#  'claim',
#  'responsibility',
#  'attack',
#  'state',
#  'attack',
#  'carry',
#  'response',
#  'road',
#  'construction',
#  'project',
#  'group',
#  'oppose',
#  'maoist',
#  'demand',
#  'construction',
#  'company',
#  'pay',
#  'male',
#  'female',
#  'worker',
#  'equally',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'attack',
#  'aim',
#  'divert',
#  'attention',
#  'security',
#  'force',
#  'operation',
#  'maguindanao',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'note',
#  'attack',
#  'coincide',
#  'fifth',
#  'anniversary',
#  'begin',
#  'france',
#  'operation',
#  'serval',
#  'bring',
#  'french',
#  'force',
#  'mali',
#  'fight',
#  'tuareg',
#  'separatist',
#  'arm',
#  'islamist',
#  'group',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'state',
#  'attack',
#  'carry',
#  'response',
#  'continue',
#  'kill',
#  'yemeni',
#  'civilian',
#  'saudiled',
#  'coalition',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'victim',
#  'abduct',
#  'lord',
#  'resistance',
#  'army',
#  'lra',
#  'increase',
#  'membership',
#  'intensify',
#  'attack',
#  'specific',
#  'motive',
#  'unknown',
#  'source',
#  'suspect',
#  'attack',
#  'aim',
#  'divert',
#  'attention',
#  'security',
#  'force',
#  'operation',
#  'maguindanao',
#  'weichan',
#  'auka',
#  'mapu',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'religion',
#  'express',
#  'discontent',
#  'perceive',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'note',
#  'attack',
#  'occur',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'schedule',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'religion',
#  'express',
#  'discontent',
#  'perceive',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'note',
#  'attack',
#  'occur',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'schedule',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'religion',
#  'express',
#  'discontent',
#  'perceive',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'note',
#  'attack',
#  'occur',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'schedule',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'religion',
#  'express',
#  'discontent',
#  'perceive',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'note',
#  'attack',
#  'occur',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'schedule',
#  'visit',
#  'chile',
#  'weichan',
#  'auka',
#  'mapu',
#  'claim',
#  'responsibility',
#  'incident',
#  'state',
#  'attack',
#  'religion',
#  'express',
#  'discontent',
#  'perceive',
#  'control',
#  'people',
#  'body',
#  'idea',
#  'act',
#  'source',
#  'note',
#  'attack',
#  'occur',
#  'three',
#  'day',
#  'pope',
#  'francis',
#  'schedule',
#  'visit',
#  'chile',
#  ...]

# %% [markdown]
# ### 8. Use Counter() function to calculate the frequency
# we can also use FreqDist in nltk package, as for this text data there are many composition (合成词) that contains '-'.

# %%
from collections import Counter
result = Counter(lemmas_sent)
result2 = result
result2.most_common(20)
# Out:
# [('source', 3159),
#  ('unknown', 3091),
#  ('motive', 3034),
#  ('specific', 3033),
#  ('attack', 2448),
#  ('state', 2092),
#  ('note', 1626),
#  ('incident', 1369),
#  ('claim', 1262),
#  ('responsibility', 1242),
#  ('suspect', 948),
#  ('victim', 843),
#  ('carry', 832),
#  ('target', 795),
#  ('may', 698),
#  ('election', 645),
#  ('retaliation', 471),
#  ('part', 403),
#  ('group', 401),
#  ('islamic', 401)]

# %% [markdown]
# ### 9. remove news-related nouns and verbs subjectively in order to perform Wordcloud

# %%
stopword_list = ['s','e','n','t','claim','source','motive','unknown','specific','state','note','claime','may','incident']  
for i in stopword_list:
    my_stopwords.add(i)
#print(my_stopwords)
result3 = remove_stopwords(lemmas_sent)
#len(result3)
result_final = Counter(result3)
result_final.most_common(20)
# Out:
# [('attack', 2448),
#  ('responsibility', 1242),
#  ('suspect', 948),
#  ('victim', 843),
#  ('carry', 832),
#  ('target', 795),
#  ('election', 645),
#  ('retaliation', 471),
#  ('part', 403),
#  ('group', 401),
#  ('islamic', 401),
#  ('member', 396),
#  ('people', 334),
#  ('schedule', 327),
#  ('maoist', 319),
#  ('large', 305),
#  ('assailant', 303),
#  ('violence', 293),
#  ('demand', 293),
#  ('trend', 292)]

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
#word_dist = nltk.FreqDist(test3)
#my_stopwords_add = my_stopwords
#stopword_list = ['s','e','n','t','source','unknown','specific','state','note','claim','may']  
#for i in stopword_list:
  #  my_stopwords.add(i)

#Mask = np.array(Image.open('D:\myjupyter\opensource\cloud.jpg'))
wordcloud = WordCloud(stopwords=my_stopwords,background_color='white', max_words = 400,
                      width=2000,height=1600).generate_from_frequencies(result_final)
plt.imshow(wordcloud)
fig=plt.gcf()
fig.set_size_inches(10,16)
plt.axis('off')
plt.show(wordcloud)
#wordcloud.to_file('2018-2020final2.png')

# %%
#wordcloud.to_file('2018-2020final2.png')

# %%
#df['Group']
region_attacks = df.Group.value_counts().reset_index()
region = region_attacks.loc[1:10,:]
region.columns = ['Group','frequency']
region
# Out:
#                                           Group  frequency
# 1                                       Taliban       4502
# 2   Islamic State of Iraq and the Levant (ISIL)       1577
# 3               Houthi extremists (Ansar Allah)       1369
# 4                                    Al-Shabaab       1103
# 5                                    Boko Haram        888
# 6                       New People's Army (NPA)        623
# 7                             Fulani extremists        585
# 8                                       Maoists        462
# 9                                   Separatists        336
# 10                            Muslim extremists        285

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#use the groupby() function to separate the data by 'Country' and calculate the number of total casualities 
#with sum() function. use the sort_values() function to sort the values in descending order and reserve the top 10.

#rename name and number in list format
name = region.Group.tolist()
num = region.frequency.tolist()

#define the colors using palette from seaborn package
colors = sns.color_palette('OrRd_r',10)

#plot vertical barplot
#plt.barh(range(len(name)), num, color = colors,)
fig, ax = plt.subplots(figsize = (15,7), edgecolor='white')
b = ax.barh(range(len(name)), num, color=colors)
#open the grid
plt.grid(color='orange',linestyle='--',linewidth=1,alpha=0.2)

for rect in b:
    w = rect.get_width()
    ax.text(w, rect.get_y()+rect.get_height()/2, '%d' %
            int(w), ha='left', va='center',fontsize = 17)

#y label
ax.set_yticks(range(len(name)),fontsize = 16,fontproperties = 'serif')
ax.set_yticklabels(name,fontsize = 18,fontproperties = 'serif')

plt.show()
#fig.savefig('GroupCrime.png',bbox_inches = 'tight')
